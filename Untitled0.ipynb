# %%
from __future__ import division
import datetime as dt
from collections import OrderedDict
import sys, os
import dateutil.relativedelta as rd
import json

import shapely
from shapely.geometry import mapping
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline  

# Set your gtfs_toolkit path here

home = '/home/araichev/'
gtfs_toolkit_path = home + 'gtfs-toolkit/'
sys.path.append(gtfs_toolkit_path)
from gtfs_toolkit.feed import *
from gtfs_toolkit.utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
feed = Feed(home + 'auckland_network_analysis/data/old_network/auckland_20140301_gtfs.zip')

# %%
linestring_by_shape = feed.get_linestring_by_shape(use_utm=False)

date = dt.date(2014, 2, 10)
rng = pd.date_range('1/1/2000', periods=24*60, freq='Min')
timestrs = [t.strftime('%H:%M:%S') for t in rng]
loc = time_it(feed.get_vehicles_locations)(linestring_by_shape, date, timestrs)
loc
# Out:
# Timing get_vehicles_locations
# 2014-09-19 12:14:21.903555 Began process
# 2014-09-19 12:14:41.949623
#  Finished in 0.33 min
#        route_id service_id  trip_id  \
# 0        100348          2  1125315
# 1        100348          2  1125315
# 2        100348          2  1125315
# 3        100348          2  1125315
# 4        100348          2  1125315
# 5        100348          2  1125315
# 6        100348          2  1125315
# 7        100348          2  1125315
# 8        100348          2  1125315
# 9        100348          2  1125315
# 10       100348          2  1125315
# 11       100348          2  1125315
# 12       100348          2  1125315
# 13       100348          2  1125315
# 14       100348          2  1125315
# 15       100348          2  1125315
# 16       100348          2  1125315
# 17       100348          2  1125315
# 18       100348          2  1125315
# 19       100348          2  1125315
# 20       100348          2  1125315
# ...

# %%
loc.to_csv('auckland_bus_locations_20140210.csv', index=False)
