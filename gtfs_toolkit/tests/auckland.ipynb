# %%
from __future__ import division
import datetime as dt
from collections import OrderedDict
import sys, os
import dateutil.relativedelta as rd

import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
#%matplotlib inline  

# Set your gtfs_toolkit path here
gtfs_toolkit_path = '/home/araichev/gtfs-toolkit/'
sys.path.append(gtfs_toolkit_path)
from gtfs_toolkit.feed import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import a feed
feed_path = '/home/araichev/gtfs_explorer/data/auckland_20131029_no_school_routes.zip'
feed = Feed(feed_path)

# %%
trips_stats = feed.get_trips_stats()
trips_stats
# Out:
#       route_id  trip_id  direction_id  end_time start_time  duration  \
# 0       100348  1125315             0  17:25:00   16:05:00  1.333333
# 1       100348  1125389             0  18:10:00   16:35:00  1.583333
# 2       100348  1125481             0  18:25:00   17:05:00  1.333333
# 3       100348  1125555             0  19:00:00   17:40:00  1.333333
# 4       100348  1125629             0  19:20:00   18:10:00  1.166667
# 5       100348   492842             1  07:00:00   05:55:00  1.083333
# 6       100348   492930             1  07:25:00   06:05:00  1.333333
# 7       100348   493038             1  08:00:00   06:35:00  1.416667
# 8       100348   493126             1  08:25:00   06:54:00  1.516667
# 9       100348   493234             1  08:40:00   07:15:00  1.416667
# 10      100348   493322             1  09:45:00   08:45:00  1.000000
# 11      100882  1032186             0  07:20:00   06:50:00  0.500000
# 12      100882  1032224             0  08:00:00   07:25:00  0.583333
# ...

# %%
f = pd.merge(trips_stats, feed.routes)
g = f[['route_short_name','direction_id', 'duration', 'num_stops', 'distance']].sort('route_short_name')
g
# Out:
#       route_short_name  direction_id  duration  num_stops  distance
# 13838              005             1  0.666667         25     8.718
# 13839              005             1  0.666667         25     8.718
# 13840              005             1  0.666667         25     8.718
# 13841              005             1  0.666667         25     8.718
# 13842              005             1  0.666667         25     8.718
# 13843              005             1  0.666667         25     8.718
# 13844              005             1  0.666667         25     8.718
# 13845              005             1  0.666667         25     8.718
# 13846              005             1  0.666667         25     8.718
# 13847              005             0  0.666667         27     8.487
# 13848              005             0  0.666667         27     8.487
# 13849              005             0  0.666667         27     8.487
# 13850              005             0  0.666667         27     8.487
# ...

# %%
h = g.groupby(['route_short_name', 'direction_id']).mean().reset_index()
h.to_csv('/home/araichev/Desktop/auckland_routes_stats.csv', index=False)
