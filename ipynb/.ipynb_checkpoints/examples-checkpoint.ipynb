# %%
import sys
from pathlib import Path
import json

import pandas as pd
import numpy as np
import shapely.geometry as sg
import matplotlib

DIR = Path('..')
sys.path.append(str(DIR))

import gtfstk as gt

DATA_DIR = DIR/'data/'
matplotlib.style.use('ggplot')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# List feed

path = DATA_DIR/'cairns_gtfs.zip'
gt.list_gtfs(path)
# Out:
#             file_name  file_size
# 0  calendar_dates.txt        387
# 1          routes.txt       1478
# 2           trips.txt     143081
# 3           stops.txt      26183
# 4          agency.txt        199
# 5      stop_times.txt    2561019
# 6          shapes.txt     864694
# 7        calendar.txt        337

# %%
# Read and print feed

feed = gt.read_gtfs(path, dist_units='km')
print(feed)
# Out:
# * agency --------------------
# 	                                         agency_name  \
# 0  Department of Transport and Main Roads - Trans...
#
#                  agency_url     agency_timezone agency_lang  agency_phone
# 0  http://www.sunbus.com.au  Australia/Brisbane          en  (07)40576411
# * calendar --------------------
# 	                           service_id  monday  tuesday  wednesday  thursday  \
# 0          CNS2014-CNS_MUL-Weekday-00       1        1          1         1
# 1  CNS2014-CNS_MUL-Weekday-00-0000100       0        0          0         0
# 2         CNS2014-CNS_MUL-Saturday-00       0        0          0         0
# 3           CNS2014-CNS_MUL-Sunday-00       0        0          0         0
#
#    friday  saturday  sunday start_date  end_date
# 0       1         0       0   20140526  20141226
# 1       1         0       0   20140530  20141226
# 2       0         1       0   20140531  20141227
# 3       0         0       1   20140601  20141228
# * calendar_dates --------------------
# 	                           service_id      date  exception_type
# 0          CNS2014-CNS_MUL-Weekday-00  20140609               2
# 1          CNS2014-CNS_MUL-Weekday-00  20141006               2
# 2          CNS2014-CNS_MUL-Weekday-00  20141225               2
# 3          CNS2014-CNS_MUL-Weekday-00  20141226               2
# 4  CNS2014-CNS_MUL-Weekday-00-0000100  20141226               2
# * fare_attributes --------------------
# 	None
# * fare_rules --------------------
# 	None
# * feed_info --------------------
# 	None
# * frequencies --------------------
# 	None
# * routes --------------------
# 	   route_id route_short_name                    route_long_name route_desc  \
# 0   110-423              110                   City - Palm Cove        NaN
# 1  110N-423             110N                   City - Palm Cove        NaN
# 2   111-423              111               City - Kewarra Beach        NaN
# 3   112-423              112  Yorkeys Knob - Smithfield via JCU        NaN
# 4   113-423              113    Sunbus Depot - Cairns City Mall        NaN
#
#    route_type route_url route_color route_text_color
# 0           3       NaN      7BC142           000000
# 1           3       NaN      7BC142           000000
# 2           3       NaN      7BC142           000000
# 3           3       NaN      7BC142           000000
# 4           3       NaN      7BC142           000000
# * shapes --------------------
# 	  shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence
# 0  1100015    -16.743632    145.668255              10001
# 1  1100015    -16.743522    145.668394              10002
# 2  1100015    -16.741258    145.671277              10003
# 3  1100015    -16.744007    145.671074              10004
# 4  1100015    -16.744015    145.671074              10005
# * stops --------------------
# 	  stop_id stop_code                                      stop_name stop_desc  \
# 0  750000       NaN  Cedar Rd (Palm Cove) - Hail and Ride Location       NaN
# 1  750001       NaN                        Williams Esplanade N201       NaN
# 2  750002       NaN           Talpa Close - Hail and Ride Location       NaN
# 3  750003       NaN                              Veivers Road N203       NaN
# 4  750004       NaN      Captain Cook Hwy N3 (Cairns Tropical Zoo)       NaN
#
#     stop_lat    stop_lon zone_id stop_url  location_type parent_station
# 0 -16.743590  145.668217     NaN      NaN              0            NaN
# 1 -16.744015  145.671110     NaN      NaN              0            NaN
# 2 -16.749258  145.667893     NaN      NaN              0            NaN
# 3 -16.748213  145.663675     NaN      NaN              0            NaN
# 4 -16.757931  145.663283     NaN      NaN              0            NaN
# * stop_times --------------------
# 	                              trip_id arrival_time departure_time stop_id  \
# 0  CNS2014-CNS_MUL-Weekday-00-4165878     05:50:00       05:50:00  750337
# 1  CNS2014-CNS_MUL-Weekday-00-4165878     05:50:00       05:50:00  750000
# 2  CNS2014-CNS_MUL-Weekday-00-4165878     05:52:00       05:52:00  750001
# 3  CNS2014-CNS_MUL-Weekday-00-4165878     05:54:00       05:54:00  750002
# 4  CNS2014-CNS_MUL-Weekday-00-4165878     05:55:00       05:55:00  750003
#
#    stop_sequence  pickup_type  drop_off_type
# 0              1            0              0
# 1              2            0              0
# 2              3            0              0
# 3              4            0              0
# 4              5            0              0
# * transfers --------------------
# 	None
# * trips --------------------
# 	  route_id                  service_id                             trip_id  \
# 0  110-423  CNS2014-CNS_MUL-Weekday-00  CNS2014-CNS_MUL-Weekday-00-4165878
# 1  110-423  CNS2014-CNS_MUL-Weekday-00  CNS2014-CNS_MUL-Weekday-00-4165879
# 2  110-423  CNS2014-CNS_MUL-Weekday-00  CNS2014-CNS_MUL-Weekday-00-4165880
# 3  110-423  CNS2014-CNS_MUL-Weekday-00  CNS2014-CNS_MUL-Weekday-00-4165881
# 4  110-423  CNS2014-CNS_MUL-Weekday-00  CNS2014-CNS_MUL-Weekday-00-4165882
#
#               trip_headsign  direction_id block_id shape_id
# 0  The Pier Cairns Terminus             0      NaN  1100023
# 1  The Pier Cairns Terminus             0      NaN  1100023
# 2  The Pier Cairns Terminus             0      NaN  1100023
# 3  The Pier Cairns Terminus             0      NaN  1100023
# 4  The Pier Cairns Terminus             0      NaN  1100023
# * dist_units --------------------
# 	km

# %%
feed.describe()
# Out:
#                            indicator  \
# 0                           agencies
# 1                           timezone
# 2                         start_date
# 3                           end_date
# 4                         num_routes
# 5                          num_trips
# 6                          num_stops
# 7                         num_shapes
# 8                        sample_date
# 9   num_routes_active_on_sample_date
# 10   num_trips_active_on_sample_date
# 11   num_stops_active_on_sample_date
#
#                                                 value
# 0   [Department of Transport and Main Roads - Tran...
# 1                                  Australia/Brisbane
# 2                                            20140526
# 3                                            20141228
# 4                                                  22
# 5                                                1339
# 6                                                 416
# 7                                                  54
# 8                                            20140529
# 9                                                  20
# 10                                                622
# 11                                                416

# %%
# Validate

feed.validate()
# Out:
#       type                                  message                    table  \
# 0  warning                             Feed expired  calendar/calendar_dates
# 1  warning  Repeated pair (trip_id, departure_time)               stop_times
#
#                                                 rows
# 0                                                 []
# 1  [17710, 17722, 17730, 17732, 17736, 17739, 177...

# %%
# Compute trip stats

trip_stats = feed.compute_trip_stats()
trip_stats.head().T
# Out:
#                                                  703  \
# trip_id           CNS2014-CNS_MUL-Weekday-00-4165878
# route_id                                     110-423
# route_short_name                                 110
# route_type                                         3
# direction_id                                       0
# shape_id                                     1100023
# num_stops                                         35
# start_time                                  05:50:00
# end_time                                    06:50:00
# start_stop_id                                 750337
# end_stop_id                                   750449
# is_loop                                            0
# duration                                           1
# distance                                     32.5071
# speed                                        32.5071
#
#                                                   0    \
# trip_id           CNS2014-CNS_MUL-Saturday-00-4165937
# route_id                                      110-423
# route_short_name                                  110
# route_type                                          3
# direction_id                                        0
# shape_id                                      1100023
# num_stops                                          35
# start_time                                   06:16:00
# end_time                                     07:10:00
# start_stop_id                                  750337
# end_stop_id                                    750449
# is_loop                                             0
# duration                                          0.9
# distance                                      32.5071
# speed                                          36.119
#
#                                                  704  \
# trip_id           CNS2014-CNS_MUL-Weekday-00-4165879
# route_id                                     110-423
# route_short_name                                 110
# route_type                                         3
# direction_id                                       0
# shape_id                                     1100023
# num_stops                                         35
# start_time                                  06:20:00
# end_time                                    07:20:00
# start_stop_id                                 750337
# end_stop_id                                   750449
# is_loop                                            0
# duration                                           1
# distance                                     32.5071
# speed                                        32.5071
#
#                                                  705  \
# trip_id           CNS2014-CNS_MUL-Weekday-00-4165880
# route_id                                     110-423
# route_short_name                                 110
# route_type                                         3
# direction_id                                       0
# shape_id                                     1100023
# num_stops                                         35
# start_time                                  06:50:00
# end_time                                    07:50:00
# start_stop_id                                 750337
# end_stop_id                                   750449
# is_loop                                            0
# duration                                           1
# distance                                     32.5071
# speed                                        32.5071
#
#                                                  706
# trip_id           CNS2014-CNS_MUL-Weekday-00-4165881
# route_id                                     110-423
# route_short_name                                 110
# route_type                                         3
# direction_id                                       0
# shape_id                                     1100023
# num_stops                                         35
# start_time                                  07:15:00
# end_time                                    08:20:00
# start_stop_id                                 750337
# end_stop_id                                   750449
# is_loop                                            0
# duration                                     1.08333
# distance                                     32.5071
# speed                                        30.0066

# %%
# Add shape_dist_traveled column to stop times

feed = feed.append_dist_to_stop_times(trip_stats)
feed.stop_times.head().T
# Out:
#                                                    17709  \
# trip_id              CNS2014-CNS_MUL-Saturday-00-4165937
# arrival_time                                    06:16:00
# departure_time                                  06:16:00
# stop_id                                           750337
# stop_sequence                                          1
# pickup_type                                            0
# drop_off_type                                          0
# shape_dist_traveled                                    0
#
#                                                    17710  \
# trip_id              CNS2014-CNS_MUL-Saturday-00-4165937
# arrival_time                                    06:16:00
# departure_time                                  06:16:00
# stop_id                                           750000
# stop_sequence                                          2
# pickup_type                                            0
# drop_off_type                                          0
# shape_dist_traveled                              0.46864
#
#                                                    17711  \
# trip_id              CNS2014-CNS_MUL-Saturday-00-4165937
# arrival_time                                    06:18:00
# departure_time                                  06:18:00
# stop_id                                           750001
# stop_sequence                                          3
# pickup_type                                            0
# drop_off_type                                          0
# shape_dist_traveled                              1.19038
#
#                                                    17712  \
# trip_id              CNS2014-CNS_MUL-Saturday-00-4165937
# arrival_time                                    06:20:00
# departure_time                                  06:20:00
# stop_id                                           750002
# stop_sequence                                          4
# pickup_type                                            0
# drop_off_type                                          0
# shape_dist_traveled                              2.15478
#
#                                                    17713
# trip_id              CNS2014-CNS_MUL-Saturday-00-4165937
# arrival_time                                    06:21:00
# departure_time                                  06:21:00
# stop_id                                           750003
# stop_sequence                                          5
# pickup_type                                            0
# drop_off_type                                          0
# shape_dist_traveled                                2.619

# %%
# Choose study dates

week = feed.get_first_week()
dates = [week[4], week[6]]  # First Friday and Sunday
dates
# Out:
# ['20140530', '20140601']

# %%
# Compute feed time series

ts = feed.compute_feed_time_series(trip_stats, dates, freq='6H')
ts
# Out:
#                      num_trip_ends  num_trip_starts  num_trips  \
# 2014-05-30 00:00:00           14.0             17.0       17.0
# 2014-05-30 06:00:00          214.0            240.0      242.0
# 2014-05-30 12:00:00          248.0            253.0      281.0
# 2014-05-30 18:00:00          155.0            126.0      160.0
# 2014-05-31 00:00:00            NaN              NaN        NaN
# 2014-05-31 06:00:00            NaN              NaN        NaN
# 2014-05-31 12:00:00            NaN              NaN        NaN
# 2014-05-31 18:00:00            NaN              NaN        NaN
# 2014-06-01 00:00:00            0.0              0.0        0.0
# 2014-06-01 06:00:00           68.0             80.0       80.0
# 2014-06-01 12:00:00          111.0            110.0      122.0
# 2014-06-01 18:00:00           84.0             76.0       87.0
#
#                      service_distance  service_duration  service_speed
# 2014-05-30 00:00:00        582.579000         12.450000      46.793494
# 2014-05-30 06:00:00       4954.224929        173.800000      28.505322
# 2014-05-30 12:00:00       5505.336088        193.216667      28.493070
# 2014-05-30 18:00:00       3248.283810        103.550000      31.369230
# 2014-05-31 00:00:00               NaN               NaN            NaN
# 2014-05-31 06:00:00               NaN               NaN            NaN
# 2014-05-31 12:00:00               NaN               NaN            NaN
# 2014-05-31 18:00:00               NaN               NaN            NaN
# 2014-06-01 00:00:00         26.198832          0.766667      34.172389
# 2014-06-01 06:00:00       1794.087189         55.766667      32.171318
# 2014-06-01 12:00:00       2615.694132         81.516667      32.087845
# 2014-06-01 18:00:00       1954.866162         59.633333      32.781434

# %%
gt.downsample(ts, freq='12H')
# Out:
#                      num_trip_ends  num_trip_starts  num_trips  \
# 2014-05-30 00:00:00          228.0            257.0      256.0
# 2014-05-30 12:00:00          403.0            379.0      408.0
# 2014-05-31 00:00:00            NaN              NaN        NaN
# 2014-05-31 12:00:00            NaN              NaN        NaN
# 2014-06-01 00:00:00           68.0             80.0       80.0
# 2014-06-01 12:00:00          195.0            186.0      198.0
#
#                      service_distance  service_duration  service_speed
# 2014-05-30 00:00:00       5536.803929        186.250000      29.727806
# 2014-05-30 12:00:00       8753.619898        296.766667      29.496641
# 2014-05-31 00:00:00               NaN               NaN            NaN
# 2014-05-31 12:00:00               NaN               NaN            NaN
# 2014-06-01 00:00:00       1820.286021         56.533333      32.198456
# 2014-06-01 12:00:00       4570.560294        141.150000      32.380873

# %%
# Compute feed stats for first week

feed_stats = feed.compute_feed_stats(trip_stats, week)
feed_stats
# Out:
#        date  num_stops  num_routes  num_trips  num_trip_starts  num_trip_ends  \
# 3  20140526        416          20        622              622            617
# 4  20140527        416          20        622              622            617
# 5  20140528        416          20        622              622            617
# 6  20140529        416          20        622              622            617
# 0  20140530        416          22        636              636            617
# 1  20140531        415          22        437              437            415
# 2  20140601        411          14        266              266            263
#
#    peak_num_trips peak_start_time peak_end_time  service_distance  \
# 3              39        08:16:00      08:18:00      13774.027234
# 4              39        08:16:00      08:18:00      13774.027234
# 5              39        08:16:00      08:18:00      13774.027234
# 6              39        08:16:00      08:18:00      13774.027234
# 0              39        08:16:00      08:18:00      14290.423827
# 1              23        17:28:00      17:37:00       9911.526097
# 2              17        14:31:00      14:37:00       6390.846315
#
#    service_duration  service_speed
# 3        472.600000      29.145212
# 4        472.600000      29.145212
# 5        472.600000      29.145212
# 6        472.600000      29.145212
# 0        483.016667      29.585778
# 1        310.400000      31.931463
# 2        197.683333      32.328706

# %%
from plotnine import *

ggplot(feed_stats, aes(x='date', y='service_duration', group=1))\
  + geom_line(colour="red", linetype="dashed", size=1.5)\
  + geom_point(colour="red", size=4, shape='o', fill="white")\
  + xlab("Date") + ylab("Service duration (h)")\
  + ggtitle("First Monday--Sunday week of feed")
# Out:
# <ggplot: (-9223363258160620926)>

# %%
# Compute route time series

rts = feed.compute_route_time_series(trip_stats, dates, freq='6H')
rts.head()
# Out:
# indicator           num_trip_ends                                           \
# route_id                  110-423 110N-423 111-423 112-423 113-423 120-423
# 2014-05-30 00:00:00           0.0      9.0     0.0     0.0     0.0     0.0
# 2014-05-30 06:00:00          19.0      0.0    18.0     4.0     3.0    11.0
# 2014-05-30 12:00:00          24.0      0.0    24.0     6.0     2.0    12.0
# 2014-05-30 18:00:00          15.0      0.0    15.0     5.0     1.0     9.0
# 2014-05-31 00:00:00           NaN      NaN     NaN     NaN     NaN     NaN
#
# indicator                                               ...    service_speed  \
# route_id            120N-423 121-423 122-423 123-423    ...         131N-423
# 2014-05-30 00:00:00      0.0     0.0     0.0     0.0    ...              NaN
# 2014-05-30 06:00:00      0.0    13.0    13.0    21.0    ...              NaN
# 2014-05-30 12:00:00      0.0    13.0    12.0    24.0    ...              NaN
# 2014-05-30 18:00:00      2.0     8.0     8.0    14.0    ...        24.067374
# 2014-05-31 00:00:00      NaN     NaN     NaN     NaN    ...              NaN
#
# indicator                                                                   \
# route_id               133-423    140-423   140N-423    141-423    142-423
# 2014-05-30 00:00:00  29.675914  26.255898  46.755126        NaN        NaN
# 2014-05-30 06:00:00  24.905870  25.620285        NaN  20.802088  26.021598
# 2014-05-30 12:00:00  24.743574  25.593499        NaN  20.809505  26.433521
# 2014-05-30 18:00:00  28.375748  26.830956        NaN  21.014223  26.385164
# 2014-05-31 00:00:00        NaN        NaN        NaN        NaN        NaN
#
# indicator
# route_id               143-423   143W-423    150-423  150E-423
# 2014-05-30 00:00:00        NaN        NaN        NaN       NaN
# 2014-05-30 06:00:00  24.366138        NaN  31.565566       NaN
# 2014-05-30 12:00:00  24.377598        NaN  31.524480       NaN
# 2014-05-30 18:00:00  23.786714  30.331218  31.702986  34.12138
# 2014-05-31 00:00:00        NaN        NaN        NaN       NaN
#
# [5 rows x 132 columns]

# %%
# Slice time series

inds = ['service_distance', 'service_duration', 'service_speed']
rids = ['110-423', '110N-423']

rts.loc[:, (inds, rids)]
# Out:
# indicator           service_distance             service_duration            \
# route_id                     110-423    110N-423          110-423  110N-423
# 2014-05-30 00:00:00         6.636699  399.508778         0.200000  7.916667
# 2014-05-30 06:00:00       671.016117    0.000000        20.816667  0.000000
# 2014-05-30 12:00:00       770.365217    0.000000        23.933333  0.000000
# 2014-05-30 18:00:00       446.205029    0.000000        12.400000  0.000000
# 2014-05-31 00:00:00              NaN         NaN              NaN       NaN
# 2014-05-31 06:00:00              NaN         NaN              NaN       NaN
# 2014-05-31 12:00:00              NaN         NaN              NaN       NaN
# 2014-05-31 18:00:00              NaN         NaN              NaN       NaN
# 2014-06-01 00:00:00         2.227621         NaN         0.066667       NaN
# 2014-06-01 06:00:00       276.777526         NaN         8.000000       NaN
# 2014-06-01 12:00:00       379.349832         NaN        11.000000       NaN
# 2014-06-01 18:00:00       353.244573         NaN        10.266667       NaN
#
# indicator           service_speed
# route_id                  110-423   110N-423
# 2014-05-30 00:00:00     33.183495  50.464267
# 2014-05-30 06:00:00     32.234561        NaN
# 2014-05-30 12:00:00     32.187962        NaN
# 2014-05-30 18:00:00     35.984277        NaN
# 2014-05-31 00:00:00           NaN        NaN
# 2014-05-31 06:00:00           NaN        NaN
# 2014-05-31 12:00:00           NaN        NaN
# 2014-05-31 18:00:00           NaN        NaN
# 2014-06-01 00:00:00     33.414321        NaN
# 2014-06-01 06:00:00     34.597191        NaN
# 2014-06-01 12:00:00     34.486348        NaN
# 2014-06-01 18:00:00     34.406939        NaN

# %%
# Compute trip locations for every hour

rng = pd.date_range('1/1/2000', periods=24, freq='H')
times = [t.strftime('%H:%M:%S') for t in rng]
loc = feed.locate_trips(dates[0], times)
loc.head()
# Out:
#                               trip_id  rel_dist      time route_id  \
# 0  CNS2014-CNS_MUL-Weekday-00-4165878  0.152945  06:00:00  110-423
# 1  CNS2014-CNS_MUL-Weekday-00-4165879  0.720587  07:00:00  110-423
# 2  CNS2014-CNS_MUL-Weekday-00-4165880  0.152945  07:00:00  110-423
# 3  CNS2014-CNS_MUL-Weekday-00-4165881  0.720587  08:00:00  110-423
# 4  CNS2014-CNS_MUL-Weekday-00-4165882  0.202283  08:00:00  110-423
#
#    direction_id shape_id         lon        lat
# 0             0  1100023  145.669490 -16.762839
# 1             0  1100023  145.732413 -16.865060
# 2             0  1100023  145.669490 -16.762839
# 3             0  1100023  145.732413 -16.865060
# 4             0  1100023  145.675422 -16.768954

# %%
# Build a route timetable

route_id = feed.routes['route_id'].iat[0]
feed.build_route_timetable(route_id, dates).T
# Out:
#                                                   0      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   05:50:00
# departure_time                                 05:50:00
# stop_id                                          750337
# stop_sequence                                         1
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                                   0
# date                                           20140530
#
#                                                   1      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   05:50:00
# departure_time                                 05:50:00
# stop_id                                          750000
# stop_sequence                                         2
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                             0.46864
# date                                           20140530
#
#                                                   2      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   05:52:00
# departure_time                                 05:52:00
# stop_id                                          750001
# stop_sequence                                         3
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                             1.19038
# date                                           20140530
#
#                                                   3      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   05:54:00
# departure_time                                 05:54:00
# stop_id                                          750002
# stop_sequence                                         4
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                             2.15478
# date                                           20140530
#
#                                                   4      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   05:55:00
# departure_time                                 05:55:00
# stop_id                                          750003
# stop_sequence                                         5
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                               2.619
# date                                           20140530
#
#                                                   5      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   05:57:00
# departure_time                                 05:57:00
# stop_id                                          750004
# stop_sequence                                         6
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                             3.85331
# date                                           20140530
#
#                                                   6      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   05:59:00
# departure_time                                 05:59:00
# stop_id                                          750005
# stop_sequence                                         7
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                             4.76089
# date                                           20140530
#
#                                                   7      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   06:00:00
# departure_time                                 06:00:00
# stop_id                                          750006
# stop_sequence                                         8
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                             4.97181
# date                                           20140530
#
#                                                   8      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   06:01:00
# departure_time                                 06:01:00
# stop_id                                          750007
# stop_sequence                                         9
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                             5.38468
# date                                           20140530
#
#                                                   9      \
# route_id                                        110-423
# service_id                   CNS2014-CNS_MUL-Weekday-00
# trip_id              CNS2014-CNS_MUL-Weekday-00-4165878
# trip_headsign                  The Pier Cairns Terminus
# direction_id                                          0
# block_id                                            NaN
# shape_id                                        1100023
# arrival_time                                   06:02:00
# departure_time                                 06:02:00
# stop_id                                          750008
# stop_sequence                                        10
# pickup_type                                           0
# drop_off_type                                         0
# shape_dist_traveled                             5.91894
# date                                           20140530
#
#                                    ...                  \
# route_id                           ...
# service_id                         ...
# trip_id                            ...
# trip_headsign                      ...
# direction_id                       ...
# block_id                           ...
# shape_id                           ...
# arrival_time                       ...
# departure_time                     ...
# stop_id                            ...
# stop_sequence                      ...
# pickup_type                        ...
# drop_off_type                      ...
# shape_dist_traveled                ...
# date                               ...
#
#                                                  30963  \
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  23:50:00
# departure_time                                23:50:00
# stop_id                                         750344
# stop_sequence                                       23
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                              23.39
# date                                          20140601
#
#                                                  30964  \
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  23:51:00
# departure_time                                23:51:00
# stop_id                                         750343
# stop_sequence                                       24
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                            23.9469
# date                                          20140601
#
#                                                  30965  \
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  23:52:00
# departure_time                                23:52:00
# stop_id                                         750342
# stop_sequence                                       25
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                            24.5038
# date                                          20140601
#
#                                                  30966  \
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  23:54:00
# departure_time                                23:54:00
# stop_id                                         750036
# stop_sequence                                       26
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                            25.6176
# date                                          20140601
#
#                                                  30967  \
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  23:54:00
# departure_time                                23:54:00
# stop_id                                         750037
# stop_sequence                                       27
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                            25.6176
# date                                          20140601
#
#                                                  30968  \
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  23:56:00
# departure_time                                23:56:00
# stop_id                                         750038
# stop_sequence                                       28
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                            26.7315
# date                                          20140601
#
#                                                  30969  \
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  23:59:00
# departure_time                                23:59:00
# stop_id                                         750339
# stop_sequence                                       29
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                            28.4022
# date                                          20140601
#
#                                                  30970  \
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  24:01:00
# departure_time                                24:01:00
# stop_id                                         750039
# stop_sequence                                       30
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                             29.516
# date                                          20140601
#
#                                                  30971  \
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  24:02:00
# departure_time                                24:02:00
# stop_id                                         750040
# stop_sequence                                       31
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                            30.0729
# date                                          20140601
#
#                                                  30972
# route_id                                       110-423
# service_id                   CNS2014-CNS_MUL-Sunday-00
# trip_id              CNS2014-CNS_MUL-Sunday-00-4166102
# trip_headsign                                Palm Cove
# direction_id                                         1
# block_id                                           NaN
# shape_id                                       1100016
# arrival_time                                  24:04:00
# departure_time                                24:04:00
# stop_id                                         750338
# stop_sequence                                       32
# pickup_type                                          0
# drop_off_type                                        0
# shape_dist_traveled                            31.1867
# date                                          20140601
#
# [15 rows x 3050 columns]

# %%
# Compute screen line counts

path = DATA_DIR/'cairns_screen_line.geojson'
with path.open() as src:
    line = json.load(src)
    line = sg.shape(line['features'][0]['geometry'])
print(line)

feed.compute_screen_line_counts(line, dates)
# Out:
# LINESTRING (145.7326126098633 -16.84915165200684, 145.7393932342529 -16.84999364745065)
#         date                             trip_id route_id route_short_name  \
# 0   20140530  CNS2014-CNS_MUL-Weekday-00-4166383  120-423              120
# 1   20140530  CNS2014-CNS_MUL-Weekday-00-4166383  120-423              120
# 2   20140530  CNS2014-CNS_MUL-Weekday-00-4166384  120-423              120
# 3   20140530  CNS2014-CNS_MUL-Weekday-00-4166384  120-423              120
# 34  20140530  CNS2014-CNS_MUL-Weekday-00-4166400  120-423              120
# 35  20140530  CNS2014-CNS_MUL-Weekday-00-4166400  120-423              120
# 4   20140530  CNS2014-CNS_MUL-Weekday-00-4166385  120-423              120
# 5   20140530  CNS2014-CNS_MUL-Weekday-00-4166385  120-423              120
# 36  20140530  CNS2014-CNS_MUL-Weekday-00-4166401  120-423              120
# 37  20140530  CNS2014-CNS_MUL-Weekday-00-4166401  120-423              120
# 6   20140530  CNS2014-CNS_MUL-Weekday-00-4166386  120-423              120
# 7   20140530  CNS2014-CNS_MUL-Weekday-00-4166386  120-423              120
# 38  20140530  CNS2014-CNS_MUL-Weekday-00-4166402  120-423              120
# 39  20140530  CNS2014-CNS_MUL-Weekday-00-4166402  120-423              120
# 8   20140530  CNS2014-CNS_MUL-Weekday-00-4166387  120-423              120
# 9   20140530  CNS2014-CNS_MUL-Weekday-00-4166387  120-423              120
# 40  20140530  CNS2014-CNS_MUL-Weekday-00-4166403  120-423              120
# 41  20140530  CNS2014-CNS_MUL-Weekday-00-4166403  120-423              120
# 10  20140530  CNS2014-CNS_MUL-Weekday-00-4166388  120-423              120
# 11  20140530  CNS2014-CNS_MUL-Weekday-00-4166388  120-423              120
# 42  20140530  CNS2014-CNS_MUL-Weekday-00-4166404  120-423              120
# 43  20140530  CNS2014-CNS_MUL-Weekday-00-4166404  120-423              120
# 12  20140530  CNS2014-CNS_MUL-Weekday-00-4166389  120-423              120
# 13  20140530  CNS2014-CNS_MUL-Weekday-00-4166389  120-423              120
# 44  20140530  CNS2014-CNS_MUL-Weekday-00-4166405  120-423              120
# 45  20140530  CNS2014-CNS_MUL-Weekday-00-4166405  120-423              120
# 14  20140530  CNS2014-CNS_MUL-Weekday-00-4166390  120-423              120
# 15  20140530  CNS2014-CNS_MUL-Weekday-00-4166390  120-423              120
# 46  20140530  CNS2014-CNS_MUL-Weekday-00-4166406  120-423              120
# 47  20140530  CNS2014-CNS_MUL-Weekday-00-4166406  120-423              120
# ..       ...                                 ...      ...              ...
# 84  20140601   CNS2014-CNS_MUL-Sunday-00-4166450  120-423              120
# 85  20140601   CNS2014-CNS_MUL-Sunday-00-4166450  120-423              120
# 70  20140601   CNS2014-CNS_MUL-Sunday-00-4166443  120-423              120
# 71  20140601   CNS2014-CNS_MUL-Sunday-00-4166443  120-423              120
# 86  20140601   CNS2014-CNS_MUL-Sunday-00-4166451  120-423              120
# 87  20140601   CNS2014-CNS_MUL-Sunday-00-4166451  120-423              120
# 72  20140601   CNS2014-CNS_MUL-Sunday-00-4166444  120-423              120
# 73  20140601   CNS2014-CNS_MUL-Sunday-00-4166444  120-423              120
# 88  20140601   CNS2014-CNS_MUL-Sunday-00-4166452  120-423              120
# 89  20140601   CNS2014-CNS_MUL-Sunday-00-4166452  120-423              120
# 74  20140601   CNS2014-CNS_MUL-Sunday-00-4166445  120-423              120
# 75  20140601   CNS2014-CNS_MUL-Sunday-00-4166445  120-423              120
# 90  20140601   CNS2014-CNS_MUL-Sunday-00-4166453  120-423              120
# 91  20140601   CNS2014-CNS_MUL-Sunday-00-4166453  120-423              120
# 76  20140601   CNS2014-CNS_MUL-Sunday-00-4166446  120-423              120
# 77  20140601   CNS2014-CNS_MUL-Sunday-00-4166446  120-423              120
# 92  20140601   CNS2014-CNS_MUL-Sunday-00-4166454  120-423              120
# 93  20140601   CNS2014-CNS_MUL-Sunday-00-4166454  120-423              120
# 78  20140601   CNS2014-CNS_MUL-Sunday-00-4166447  120-423              120
# 79  20140601   CNS2014-CNS_MUL-Sunday-00-4166447  120-423              120
# 94  20140601   CNS2014-CNS_MUL-Sunday-00-4166455  120-423              120
# 95  20140601   CNS2014-CNS_MUL-Sunday-00-4166455  120-423              120
# 80  20140601   CNS2014-CNS_MUL-Sunday-00-4166448  120-423              120
# 81  20140601   CNS2014-CNS_MUL-Sunday-00-4166448  120-423              120
# 96  20140601   CNS2014-CNS_MUL-Sunday-00-4166456  120-423              120
# 97  20140601   CNS2014-CNS_MUL-Sunday-00-4166456  120-423              120
# 82  20140601   CNS2014-CNS_MUL-Sunday-00-4166449  120-423              120
# 83  20140601   CNS2014-CNS_MUL-Sunday-00-4166449  120-423              120
# 98  20140601   CNS2014-CNS_MUL-Sunday-00-4166457  120-423              120
# 99  20140601   CNS2014-CNS_MUL-Sunday-00-4166457  120-423              120
#
#    crossing_time  orientation
# 0       05:42:28           -1
# 1       05:50:28            1
# 2       06:42:28           -1
# 3       06:50:28            1
# 34      07:31:32           -1
# 35      07:39:28            1
# 4       07:42:28           -1
# 5       07:50:28            1
# 36      08:31:32           -1
# 37      08:39:28            1
# 6       08:42:28           -1
# 7       08:50:28            1
# 38      09:31:32           -1
# 39      09:39:28            1
# 8       09:42:28           -1
# 9       09:50:28            1
# 40      10:31:32           -1
# 41      10:39:28            1
# 10      10:42:28           -1
# 11      10:50:28            1
# 42      11:31:32           -1
# 43      11:39:28            1
# 12      11:42:28           -1
# 13      11:50:28            1
# 44      12:31:32           -1
# 45      12:39:28            1
# 14      12:42:28           -1
# 15      12:50:28            1
# 46      13:31:32           -1
# 47      13:39:28            1
# ..           ...          ...
# 84      08:47:32           -1
# 85      08:55:28            1
# 70      09:58:28           -1
# 71      10:06:28            1
# 86      10:47:32           -1
# 87      10:55:28            1
# 72      11:58:28           -1
# 73      12:06:28            1
# 88      12:47:32           -1
# 89      12:55:28            1
# 74      13:58:28           -1
# 75      14:06:28            1
# 90      14:47:32           -1
# 91      14:55:28            1
# 76      15:58:28           -1
# 77      16:06:28            1
# 92      16:47:32           -1
# 93      16:55:28            1
# 78      17:58:28           -1
# 79      18:06:28            1
# 94      18:47:32           -1
# 95      18:55:28            1
# 80      19:58:28           -1
# 81      20:06:28            1
# 96      20:47:32           -1
# 97      20:55:28            1
# 82      21:58:28           -1
# 83      22:06:28            1
# 98      22:47:32           -1
# 99      22:55:28            1
#
# [100 rows x 6 columns]
